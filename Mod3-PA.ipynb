# %%
#7.4 
things = ["mozzarella", "cindarella", "salmonella"]

#7.5
things[1] = things[1].capitalize()
print(things)

#7.6
things[0] = things[0].capitalize()
print(things)

#7.7
things.remove('salmonella')
print(things)

#9.1 
def good():
    people = ["Harry", "Ron", "Hermione"]
    return people
print(good())

#9.2
def get_odds():
    for number in range(10):
        if number % 2 == 1:
            yield number
count = 0 

for value in get_odds():
    count += 1
    if count == 3:
        print(value)
        break
# Out:
# ['mozzarella', 'Cindarella', 'salmonella']
# ['Mozzarella', 'Cindarella', 'salmonella']
# ['Mozzarella', 'Cindarella']
# ['Harry', 'Ron', 'Hermione']
# 5
